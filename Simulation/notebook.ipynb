# %%
from model import vertical_fdi_separated, vertical_fdi_integrated

# %%
results = vertical_fdi_integrated()
#print(results)
for k, v in results.items():
    print(f'{k}: {round(v, 2)}')
# Out:
# ball_bearing_price: 6
# machine_price: 126.0
# machine_quantity: 57.0
# bearing_quantity: 114.0
# integrated_profit: 5498.0
