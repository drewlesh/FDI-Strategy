# %%
from model import vertical_fdi_separated

# %%
results = vertical_fdi_separated()
#print(results)
for k, v in results.items():
    print(f'{k}: {round(v, 2)}')
# Out:
# ball_bearing price: 60.5
# machine_price: 182.5
# machines_quanity: 28.75
# bearings_quantity: 57.5
# slovenian_profit: 3306.25
# greek_profit: 1653.12
